# %% [markdown]
# # 第1-3课：如何分区和绘图

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
fig, ax = plt.subplots(3, 3, sharex='col', sharey='row')

# %%
fig, ax = plt.subplots(3, 3, sharex='col', sharey='row')
for i in range(3):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)), fontsize=18, ha='center')

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax2 = fig.add_axes([0.6, 0.5, 0.2, 0.3])

# %% [markdown]
# fig.add_axes([0.1, 0.1, 0.8, 0.8]) 中的参数，是按照 [left, bottom, width, height] 的顺序，设置坐标系相对于图像对象的位置以及坐标系对象的长宽（其数值是相对于图像对象长宽的比例，width=0.8 意味着坐标系对象的宽度是图像对象宽度的 80%）。

# %%
from matplotlib.gridspec import GridSpec    #①

fig = plt.figure()
fig.suptitle("划分不同大小的坐标系分区")    #②

gs = GridSpec(3, 3, figure=fig)    #③
ax1 = fig.add_subplot(gs[0, :])    #④
ax2 = fig.add_subplot(gs[1, :-1])
ax3 = fig.add_subplot(gs[1:, -1])
ax4 = fig.add_subplot(gs[-1, 0])
ax5 = fig.add_subplot(gs[-1, -2])

def format_axes(fig):    
    for i, ax in enumerate(fig.axes):    #⑤
        ax.text(0.5, 0.5, "ax%d" % (i+1), va="center", ha="center")
        ax.tick_params(labelbottom=False, labelleft=False)

format_axes(fig)

# %%
import numpy as np

fig, ax = plt.subplots()
x = np.linspace(0, 2*np.pi, 100)
ax.plot(x, np.sin(x), color='blue')
ax.plot(x, np.sin(x-np.pi/3), color='r', linestyle='-.')
ax.plot(x, np.sin(x-2*np.pi/3), color='#A52A2A', linewidth=3)

# %%
plt.plot([1,2,3], [3,8,5], marker='o')

# %% [markdown]
# 这里使用 marker='o' 对坐标点指定了显示图形。marker 还可以取其他值，下表列出了可选值及其含义。
#
# 符号	说明
# '.'	实心小点
#
# ','	一个像素，其实就是什么也没显示
#
# 'o'	实心圆点
#
# 'v'	一个角指向下的三角形
#
# '^'	一个角指向上的三角形
#
# '<'	一个角指向左的三角形
#
# '>'	一个角指向右的三角形
#
# '1'	一个棱指向下的三棱形
#
# '2'	一个棱指向上的三棱形
#
# '3'	一个棱指向左的三棱形
#
# '4'	一个棱指向右的三棱形
#
# 's'	正方形
#
# 'p'	五边形
#
# '*'	星形
#
# 'h'	六边形
#
# 'H'	六边形
#
# '+'	加号 ＋ 形
#
# 'x'	乘号 × 形
#
# 'D'	菱形（对角线相等）
#
# 'd'	菱形（水平对角线较短）
# '	'
# '_'	横线符号
#
# 以下几个参数也是跟上述图形设置有关的：
#
# markersize，设置大小
#
# markerfacecolor，设置颜色
#
# markevery，指定所要设置的坐标点

# %%
plt.plot([3,8,5,2,9],
         marker='d', 
         markerfacecolor='yellow', 
         markersize=10, 
         markevery=[1,2,4])

# %%
import pandas as pd
df = pd.DataFrame({"col1":[1,2,3,4,5,6], 'col2':[9,3,8,1,5,3], 'col3':[10,8,1,5,7,3]})
plt.plot('col1', 'col2', data=df, marker='D')

# %%
df = pd.DataFrame({"col1":[1,2,3,4,5,6], 'col2':[9,3,8,1,5,3], 'col3':[10,8,1,5,7,3]})
df.plot()

# %%
a = np.arange(0, 3, .02)
b = np.arange(0, 3, .02)
c = np.exp(a)
d = c[: : -1]
plt.plot(a, c, 'k--', label="Model")
plt.plot(a, d, 'r:', label="Data")
plt.plot(a, c+d, 'b-', label="Total")
plt.legend(loc='upper right')

# %%
plt.plot([0,1,2,3,4,5], label="positive")
plt.plot([5,4,3,2,1,0], label="negative")
plt.legend(bbox_to_anchor=(0, 1), loc=3, ncol=2)
